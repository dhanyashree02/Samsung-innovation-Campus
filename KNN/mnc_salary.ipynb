# %% [markdown]
# <a href="https://colab.research.google.com/github/dhanyashree02/Samsung-innovation-Campus/blob/main/KNN/mnc_salary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = '/content/drive/MyDrive/0.Samsung CSR AIML/Resources/SIC-Artificial-Intelligence/SIC_AI_Coding_Exercises/SIC_AI_Chapter_06_Coding_Exercises/mnc_salary.csv'

# %%
import numpy as np
import time
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score

# %%
df = pd.read_csv(data)
df.head()
# Out:
#   company                  job     degree  salary_more_then_100k
# 0  google      sales executive  bachelors                      0
# 1  google      sales executive    masters                      0
# 2  google     business manager  bachelors                      1
# 3  google     business manager    masters                      1
# 4  google  computer programmer  bachelors                      0

# %%
# Separate features (X) and target (y)
X = df.drop('job', axis=1)
y = df['job']

# Convert the target variable to numerical (0 for 'No', 1 for 'Yes')
# The original code incorrectly converted all job titles to 0.
# Instead, we will one-hot encode the 'job' column to handle multiple classes.
# y = y.apply(lambda x: 1 if x == 'Yes' else 0)

# Identify categorical and numerical columns
categorical_cols = X.select_dtypes(include=['object']).columns
numerical_cols = X.select_dtypes(include=np.number).columns

# We will one-hot encode the 'job' column later after the train/test split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# Apply one-hot encoding to categorical columns after the split
X_train = pd.get_dummies(X_train, columns=categorical_cols, drop_first=True)
X_test = pd.get_dummies(X_test, columns=categorical_cols, drop_first=True)

# One-hot encode the target variable y
y_train = pd.get_dummies(y_train, drop_first=True)
y_test = pd.get_dummies(y_test, drop_first=True)

# Convert one-hot encoded y back to a single column of class labels
y_train = y_train.values.argmax(axis=1)
y_test = y_test.values.argmax(axis=1)

# %%
scaler = StandardScaler()

# Now all columns in X_train and X_test are numerical after one-hot encoding
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
start_time_knn = time.time()

knn_model = KNeighborsClassifier(n_neighbors=5)

knn_model.fit(X_train_scaled, y_train)

end_time_knn = time.time()

# %%
# Make predictions
y_pred_knn = knn_model.predict(X_test_scaled)

# Convert predictions to numerical (0 for 'No', 1 for 'Yes') if they are not already
# The predict method might return the original labels, so we ensure they are numerical
y_pred_knn_numerical = np.where(y_pred_knn == 'Yes', 1, 0)


# Calculate metrics
accuracy_knn = accuracy_score(y_test, y_pred_knn)
roc_auc_knn = roc_auc_score(y_test, y_pred_knn_numerical)
training_time_knn = end_time_knn - start_time_knn

print("=== K-Nearest Neighbors (KNN) ===")
print(f"Accuracy: {accuracy_knn:.4f}")

print(f"ROC AUC Score: {roc_auc_knn:.4f}")

print(f"Training Time: {training_time_knn:.4f} seconds")

print("\nClassification Report:")
print(classification_report(y_test, y_pred_knn))
# Out:
# === K-Nearest Neighbors (KNN) ===
# Accuracy: 0.4000
# ROC AUC Score: 0.5000
# Training Time: 0.0030 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.00      0.00      0.00         1
#
#    micro avg       0.00      0.00      0.00         3
#    macro avg       0.00      0.00      0.00         3
# weighted avg       0.00      0.00      0.00         3
#  samples avg       0.00      0.00      0.00         3
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
# Initialize and train the SVM Classifier
start_time_svm = time.time()
svm_model = SVC(kernel='rbf',
                C=1.0,
                gamma='scale',
                random_state=42)

svm_model.fit(X_train_scaled, y_train)

end_time_svm = time.time()

# Make predictions
y_pred_svm = svm_model.predict(X_test_scaled)

# Evaluate SVM model
accuracy_svm = accuracy_score(y_test, y_pred_svm)
# Note: ROC AUC score is not directly applicable for multi-class classification with SVC
# You can calculate it for each class in a one-vs-rest approach if needed, but
# for a simple comparison, accuracy and classification report are sufficient.
training_time_svm = end_time_svm - start_time_svm

print("=== Support Vector Machine (SVM) ===")
print(f"Accuracy: {accuracy_svm:.4f}")
print(f"Training Time: {training_time_svm:.4f} seconds")
print("\nClassification Report:")
print(classification_report(y_test, y_pred_svm))
# Out:
# === Support Vector Machine (SVM) ===
# Accuracy: 0.6000
# Training Time: 0.0034 seconds
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         4
#            1       0.00      0.00      0.00         1
#
#     accuracy                           0.60         5
#    macro avg       0.38      0.38      0.38         5
# weighted avg       0.60      0.60      0.60         5
